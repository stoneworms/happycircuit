# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
# 모든 열 다 보기
pd.set_option('display.max_columns', None)

# 너비 제한 없애기 (길게 나올 경우 줄바꿈 없이 한 줄에 표시)
pd.set_option('display.width', None)

# %%
data = pd.read_csv(r"C:\Users\jeong\education\data\final_dataset.csv",encoding = "utf-8")

# %%
data = data.drop(columns=["학교세부유형"])

# %%
set(data["저학년_학생수"]==data["1학년 학생수"]+data["2학년 학생수"])
# Out:
# {True}

# %%
data
# Out:
#         시도교육청       학교명    시도   시군구    행정구  읍면동        상세주소  \
# 0     전라남도교육청   가거도초등학교  전라남도   신안군    NaN  흑산면    가거도리 266
# 1     충청북도교육청    가경초등학교  충청북도   청주시    흥덕구  복대동        2443
# 2     경상남도교육청   가고파초등학교  경상남도   창원시  마산회원구  양덕동        84-3
# 3      경기도교육청    가곡초등학교   경기도  남양주시    NaN  화도읍  가곡리 279-21
# 4     충청북도교육청    가곡초등학교  충청북도   단양군    NaN  가곡면     사평리 435
# ...       ...       ...   ...   ...    ...  ...         ...
# 6129  경상북도교육청  흥해남산초등학교  경상북도   포항시     북구  흥해읍     남성리 338
# 6130  경상북도교육청  흥해서부초등학교  경상북도   포항시     북구  흥해읍     매산리 1-6
# 6131  경상북도교육청    흥해초등학교  경상북도   포항시     북구  흥해읍     약성리 100
# 6132   경기도교육청   희망대초등학교   경기도   성남시    수정구  신흥동        1232
# 6133   경기도교육청    희성초등학교   경기도   안양시    동안구  비산동      1101-1
#
#                       소재지지번주소                 소재지도로명주소         위도          경도  \
# 0       전라남도 신안군 흑산면 가거도리 266  전라남도 신안군 흑산면 가거도길 18-31  34.052552  125.130255
# 1       충청북도 청주시 흥덕구 복대동 2443     충청북도 청주시 흥덕구 장구봉로 93  36.624744  127.443619
# ...

# %%
data[data["학교명"]=="우천초등학교"]
# Out:
#            시도교육청     학교명       시도  시군구  행정구  읍면동     상세주소  \
# 4316  강원특별자치도교육청  우천초등학교  강원특별자치도  횡성군  NaN  우천면  우항리 628
#
#                       소재지지번주소                 소재지도로명주소         위도          경도  \
# 4316  강원특별자치도 횡성군 우천면 우항리 628  강원특별자치도 횡성군 우천면 수남로 319  37.461165  128.061577
#
#       이용인원  저학년_학급수  저학년_학생수  고학년_학급수  고학년_학생수  1학년 학급수  1학년 학생수  1학년 학급당 학생수  \
# 4316    63      2.0     22.0      4.0     37.0      1.0      8.0          8.0
#
#       2학년 학급수  2학년 학생수  2학년 학급당 학생수  3학년 학급수  3학년 학생수  3학년 학급당 학생수  4학년 학급수  \
# 4316      1.0     14.0         14.0      1.0     11.0         11.0      1.0
#
#       4학년 학생수  4학년 학급당 학생수  5학년 학급수  5학년 학생수  5학년 학급당 학생수  6학년 학급수  6학년 학생수  \
# 4316      5.0          5.0      1.0     11.0         11.0      1.0     10.0
#
#       6학년 학급당 학생수  특수학급 학급수  특수학급 학생수  특수학급 학급당 학생수  순회학급 학급수  순회학급 학생수  \
# 4316         10.0       1.0       4.0           4.0       0.0       0.0
#
# ...
